# %% [markdown]
# ### Task 1: Import pandas

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# ### Task 2: Load the Customers Dataset

# %%
customers = pd.read_csv('data/Customer_Dataset.csv ')
customers
# Out:
#            age         income  visits_per_month
# 0    30.483571   33893.885591          9.295377
# 1    35.615149   33126.773002          7.531726
# 2    35.896064   41139.477833          7.061051
# 3    30.712800   31292.658458          7.068540
# 4    29.209811   19693.758043          4.550164
# ..         ...            ...               ...
# 295  67.926951  103758.922780          2.640708
# 296  59.134584  111630.553709          3.820482
# 297  58.550918  111000.120344          4.169296
# 298  64.675113  104730.648314          2.832882
# 299  56.026996  113097.634498          2.183064
#
# [300 rows x 3 columns]

# %% [markdown]
# ### Task 3: Preview the Customers Data

# %%
customers.head(6)
# Out:
#          age        income  visits_per_month
# 0  30.483571  33893.885591          9.295377
# 1  35.615149  33126.773002          7.531726
# 2  35.896064  41139.477833          7.061051
# 3  30.712800  31292.658458          7.068540
# 4  29.209811  19693.758043          4.550164
# 5  25.188562  26897.351037          8.628495

# %%
customers.tail(4)
# Out:
#            age         income  visits_per_month
# 296  59.134584  111630.553709          3.820482
# 297  58.550918  111000.120344          4.169296
# 298  64.675113  104730.648314          2.832882
# 299  56.026996  113097.634498          2.183064

# %%
customers.sample(5)
# Out:
#            age         income  visits_per_month
# 221  51.196027   84307.313260          3.106430
# 189  33.951482   42550.496948          4.472730
# 295  67.926951  103758.922780          2.640708
# 244  57.857769   69461.245936          4.029156
# 168  36.096145   59154.495395          4.111409

# %% [markdown]
# Q: do random rows look different every time its run?
# A: Yes, because it picks random samples

# %% [markdown]
# ### Task 4: Load and inspect the cars dataset

# %%
cars = pd.read_csv("data/cars.csv")
print(customers.shape) 
print(customers.columns)
# Out:
# (300, 3)
# Index(['age', 'income', 'visits_per_month'], dtype='object')

# %% [markdown]
# ### Q: How many rows
# ### A: 300
# ### How many columns
# ### A: 3
# ### Column names:
# ### A: age, income, visits_per_month

# %% [markdown]
# ### Task 5: Check data types in cars

# %%
customers.dtypes
# Out:
# age                 float64
# income              float64
# visits_per_month    float64
# dtype: object

# %% [markdown]
# Q: which columns hold whole numbers:
# A: none
# Q: Which columns hold decimal numbers:
# A: visits, age, income
# Q: which columns hold text or mixed valuse:
# A: none

# %% [markdown]
# ### Task 6: Load and inspect the titanic Dataset

# %%
Titanic = pd.read_csv('data/Titanic Dataset.csv')
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# How many rows and columns:
# A: 891 rows and 15 columns
# Which column has the most missing values
# A: deck
# How do you know a value is missing
# A: there are 891 entries and the non-null count provides the values for each column that aren't null

# %% [markdown]
# ### Task 7 Summary statistics on cars

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# What is the mean mpg?
# A: 23.514573
# What is the max HP
# A: skipping for now
# What is the median weight in this dataset?
# A: 2803.5

# %% [markdown]
# ### Task 8: Summary statisitics on one column

# %%
print("mean", Titanic['fare'].mean())
print("median", Titanic['fare'].median())
print("standard dev", Titanic['fare'].std())
print("min", Titanic['fare'].min())
print("max", Titanic['fare'].max())
# Out:
# mean 32.204207968574636
# median 14.4542
# standard dev 49.693428597180905
# min 0.0
# max 512.3292

# %% [markdown]
# ### Task 9 build a DF from scratch

# %%
Store = {"product":["apples", "oranges", "grapes", "bananas"], "price":[1.99, 2.00, 3.00, 4.00], "in_stock":[True, True, False, False]}
DF = pd.DataFrame(Store)
DF.dtypes
# Out:
# product      object
# price       float64
# in_stock       bool
# dtype: object

# %% [markdown]
# ### Task 10 Discussion

# %% [markdown]
# 1.  Q: diff between shape and info
#     A: shape just gives just rows and columns, info gives everything
# 2.  Q: What is the diff between head and sample, when would sample be more useful?
#     A: head gives the first five columns and sample is random rows. When you want random data sampling.
# 3.  Q: Titanic deck column had a lot missing values. Why would it be missing?
#     A: Info may not be as easily accesible through articles provided for datasets. For Titanic, deck missing values correlates with "alive" column.

# %%
Titanic.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 605         0       3    male  36.0      1      0   15.5500        S   Third
# 837         0       3    male   NaN      0      0    8.0500        S   Third
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 56          1       2  female  21.0      0      0   10.5000        S  Second
# 478         0       3    male  22.0      0      0    7.5208        S   Third
# 573         1       3  female   NaN      0      0    7.7500        Q   Third
# 457         1       1  female   NaN      1      0   51.8625        S   First
# 62          0       1    male  45.0      1      0   83.4750        S   First
# 838         1       3    male  32.0      0      0   56.4958        S   Third
# 334         1       1  female   NaN      1      0  133.6500        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 605    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# ### AT Task 11: Describe a single colum

# %%
Titanic['age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
Titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Q1: what is the youngest age in the data set
# A: .042
# Q2 what is the oldest age
# A: 80
# Q3: What does the count row tell you? Is it the same total number of rows in the dataset? why or why not?
# A: it tells us how many rows are in it, it is not the same. Some ages had no values assigned to them in the dataset.

# %% [markdown]
# ### Task 12: Compare two datasets

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               300 non-null    float64
#  1   income            300 non-null    float64
#  2   visits_per_month  300 non-null    float64
# dtypes: float64(3)
# memory usage: 7.2 KB

# %% [markdown]
# Q: Which dataset is larger?
# A: Cars
# Q: Which dataset has more colums?
# A: Cars
# Q: Which dataset has missing or incorrect valuse, which does not?
# A: Cars: Origin has a int Dtype, should be a string? Cars: horsepower is object, should be int.
# Q: which dataset would be easier to start analyzing
# A: Customers, its smaller with less rows and columns.

# %% [markdown]
# ### Task 13: Explore the sample size

# %%
cars.sample(5, random_state=42)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 198  33.0          4          91.0         53    1795          17.4
# 396  28.0          4         120.0         79    2625          18.6
# 33   19.0          6         232.0        100    2634          13.0
# 208  13.0          8         318.0        150    3940          13.2
# 93   14.0          8         318.0        150    4237          14.5
#
#      model year  origin                    car name
# 198          76       3                 honda civic
# 396          82       1                 ford ranger
# 33           71       1                 amc gremlin
# 208          76       1  plymouth volare premier v8
# 93           73       1    plymouth fury gran sedan

# %%
cars.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 314  26.4          4         140.0         88    2870          18.1
# 165  20.0          8         262.0        110    3221          13.5
# 313  28.0          4         151.0         90    2678          16.5
# 97   18.0          6         225.0        105    3121          16.5
# 257  19.4          6         232.0         90    3210          17.2
#
#      model year  origin             car name
# 314          80       1        ford fairmont
# 165          75       1  chevrolet monza 2+2
# 313          80       1   chevrolet citation
# 97           73       1     plymouth valiant
# 257          78       1          amc concord

# %% [markdown]
# Q: what did we notice:
# A: the random_state fixed the sample content so that it was the same every time it was run. The "sample(5") changed each time.
# Q: why might we want to use random_state?
# A: It gives more control for the effect on samples when implementing changes.

# %% [markdown]
# ### Task 14: Check the shape after loading

# %%
def load_and_check(path):
    df = pd.read_csv(path)
    df.shape
    return df

load_and_check('data/cars.csv')
load_and_check('data/Titanic Dataset.csv')
load_and_check('data/Customer_Dataset.csv')
# Out:
#            age         income  visits_per_month
# 0    30.483571   33893.885591          9.295377
# 1    35.615149   33126.773002          7.531726
# 2    35.896064   41139.477833          7.061051
# 3    30.712800   31292.658458          7.068540
# 4    29.209811   19693.758043          4.550164
# ..         ...            ...               ...
# 295  67.926951  103758.922780          2.640708
# 296  59.134584  111630.553709          3.820482
# 297  58.550918  111000.120344          4.169296
# 298  64.675113  104730.648314          2.832882
# 299  56.026996  113097.634498          2.183064
#
# [300 rows x 3 columns]

# %% [markdown]
# ### Task 15: Spot the outlier

# %%
cars.sample(20)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 290  15.5          8         351.0        142    4054          14.3
# 63   14.0          8         400.0        175    4385          12.0
# 169  20.0          6         232.0        100    2914          16.0
# 11   14.0          8         340.0        160    3609           8.0
# 314  26.4          4         140.0         88    2870          18.1
# 294  34.1          4          86.0         65    1975          15.2
# 252  19.2          6         231.0        105    3535          19.2
# 354  34.5          4         100.0          ?    2320          15.8
# 122  24.0          4         121.0        110    2660          14.0
# 201  18.5          6         250.0        110    3645          16.2
# 394  44.0          4          97.0         52    2130          24.6
# 377  31.0          4          91.0         68    1970          17.6
# 348  37.7          4          89.0         62    2050          17.3
# ...

# %% [markdown]
# Horsepower column has "?" in for assigned value on some rows.
